# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Charger les données nettoyées
df = pd.read_csv('../data/clean_data.csv')

# %%
# Définir le style de visualisation
sns.set(style="whitegrid")

# %% [markdown]
# # 1. Histogrammes pour toutes les colonnes numériques

# %%
plt.figure(figsize=(12, 6))
for i, column in enumerate(['BMI', 'PhysHlth', 'Age', 'MentHlth'], 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Boxplots pour détecter les valeurs extrêmes et comprendre la distribution

# %%
plt.figure(figsize=(12, 6))
for i, column in enumerate(['BMI', 'PhysHlth', 'Age', 'MentHlth'], 1):
    plt.subplot(2, 2, i)
    sns.boxplot(y=df[column])
    plt.title(f'Box Plot of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Bar plots for categorical variables

# %%
plt.figure(figsize=(10, 8))
categorical_vars = ['HighBP', 'HighChol', 'Smoker', 'Diabetes_binary']
for i, column in enumerate(categorical_vars, 1):
    plt.subplot(2, 2, i)
    sns.countplot(data=df, x=column, palette='pastel')
    plt.title(f'Count Plot of {column}')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6008\2446144451.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='pastel')
# C:\Users\HP\AppData\Local\Temp\ipykernel_6008\2446144451.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='pastel')
# C:\Users\HP\AppData\Local\Temp\ipykernel_6008\2446144451.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='pastel')
# C:\Users\HP\AppData\Local\Temp\ipykernel_6008\2446144451.py:5: FutureWarning:
#
# ...

# %% [markdown]
# # 4. Bar plots of categorical variables against Diabetes_binary

# %%
plt.figure(figsize=(10, 8))
for i, column in enumerate(['HighBP', 'HighChol', 'Smoker'], 1):
    plt.subplot(2, 2, i)
    sns.countplot(data=df, x=column, hue="Diabetes_binary", palette='coolwarm')
    plt.title(f'{column} vs Diabetes_binary')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Heatmap de corrélation

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title('Correlation Heatmap')
plt.show()
